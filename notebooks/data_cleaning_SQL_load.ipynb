# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2 
import io

# %% [markdown]
# # Clean Trail Data

# %%
# Load trail info data
df_trail = pd.read_pickle('/Users/briangraham/insight/trailrec/data/trail_info_combined.pickle')

# Eliminate trails without descriptions
df_trail = df_trail[df_trail['description'].notnull()]

# subset trail data, eliminating uncommonly reported features with mostly NaN
df_trail = df_trail[['Altitude change', 'Altitude end', 'Altitude max', 'Altitude min',
       'Altitude start', 'Avg reverse time', 'Avg time', 'Bike type',
       'Difficulty rating', 'Direction', 'Distance climb', 'Distance down',
       'Global Ranking', 'Grade', 'Grade max', 'Grade min', 'Physical rating',
       'Ride in rain', 'Riding area', 'TTFs on trail', 'Trail Usage',
       'Trail type', 'avg_time', 'city', 'climb', 'descent', 'description',
       'distance', 'latitude', 'longitude', 'rating', 'state', 'votes',
       'Climb Difficulty', 'Distance flat']]
df_trail['votes'] = df_trail['votes'].str.replace(' votes','')
df_trail['votes'] = pd.to_numeric(df_trail['votes'])
df_trail['rating'] = df_trail['rating'].str.replace('Avg:','')
df_trail['rating'] = pd.to_numeric(df_trail['rating'])
df_trail['latitude'] = pd.to_numeric(df_trail['latitude'])
df_trail['longitude'] = pd.to_numeric(df_trail['longitude'])

# %% [markdown]
# ## Have to go through this data and remove units from strings and convert to numbers

# %%
df_trail.head()
# Out:
#                     Altitude change Altitude end Altitude max Altitude min  \
# trail_id
# 1-87-dh                   -1,508 ft       349 ft     1,857 ft       349 ft
# 10-dollar                   -191 ft     2,446 ft     2,636 ft     2,446 ft
# 10-km                       -694 ft     4,931 ft     5,625 ft     4,918 ft
# 115th-ave-connector          -46 ft     1,054 ft          NaN     1,054 ft
# 147                           -0 ft     2,638 ft     2,638 ft     2,635 ft
#
#                     Altitude start Avg reverse time  Avg time    Bike type  \
# trail_id
# 1-87-dh                   1,857 ft         00:01:40  00:12:58       DH, AM
# 10-dollar                 2,636 ft         00:15:47  00:09:03   DH, AM, XC
# 10-km                     5,625 ft              NaN  00:06:44           DH
# 115th-ave-connector       1,100 ft              NaN       NaN           XC
# 147                       2,638 ft         00:07:23  00:01:17  DH, AM, Fat
#
#                      Difficulty rating         Direction      ...       \
# trail_id                                                      ...
# 1-87-dh              Black Diamondrate  Downhill Primary      ...
# 10-dollar                     Bluerate               NaN      ...
# 10-km                Black Diamondrate               NaN      ...
# 115th-ave-connector          Whiterate               NaN      ...
# 147                           Bluerate   Both Directions      ...
#
#                        descent  \
# trail_id
# 1-87-dh              -1,513 ft
# 10-dollar              -215 ft
# 10-km                  -716 ft
# 115th-ave-connector     -54 ft
# 147                      -3 ft
#
#                                                            description  \
# trail_id
# 1-87-dh              Sustained steep and fast DH trail often used a...
# 10-dollar                         One of the original Pidherny trails.
# 10-km                The 10K trail is a good early season starting ...
# 115th-ave-connector      Short connector to access the  Osoyoos Canal.
# 147                  Short, technical trail that connects The Swamp...
#
#                      distance  latitude   longitude rating state votes  \
# trail_id
# 1-87-dh               2 miles  48.82592 -123.762540   4.55    BC    13
# 10-dollar            2,226 ft  53.98968 -122.846810   3.50    BC     8
# 10-km                2,840 ft  51.28040 -116.893354   3.20    BC     5
# 115th-ave-connector  1,417 ft  49.03372 -119.488330   1.00    BC     1
# 147                    324 ft  53.87815 -122.828430   4.00    BC     1
#
#                     Climb Difficulty Distance flat
# trail_id
# 1-87-dh                          NaN           NaN
# 10-dollar                        NaN         76 ft
# 10-km                            NaN           NaN
# 115th-ave-connector            Green         48 ft
# 147                            Green         64 ft
#
# [5 rows x 35 columns]

# %% [markdown]
# # Eliminate comments that do not match this trail subset

# %%
df_comments = pd.read_pickle('/Users/briangraham/insight/trailrec/data/trail_comments_combined.pickle')
df_comments_filtered = df_comments.join(df_trail,how='right')
df_comments_filtered = df_comments_filtered[['comment_votes','user','comment_text']]
df_comments_filtered = df_comments_filtered.dropna()

# %%
df_comments_filtered.head()
# Out:
#           comment_votes            user  \
# trail_id
# 19th-hole           + 1  blackcombterry
# 2-3481              + 0        atfarley
# 2001                + 1          amowat
# 2001                + 0      MtbSince84
# 280-s               + 0        HexAngel
#
#                                                 comment_text
# trail_id
# 19th-hole  What's 19th Hole like below the Upper Legacy c...
# 2-3481                                           Just a road
# 2001       Still some good ladders but alot gone. Big roc...
# 2001                                  Closed due to logging.
# 280-s      Gently insistent ascent even this unfit geezer...

# %% [markdown]
# # Eliminate ridelogs that do not match this trail subset

# %%
df_ridelogs = pd.read_pickle('/Users/briangraham/insight/trailrec/data/trail_ridelogs_combined.pickle')
df_ridelogs_match = ridelogs.join(df_trail,how='right')
df_ridelogs_match = df_ridelogs_match[['ride_date','rider_url','rider_name','rider_state','rider_city','ride_difficulty_string']]
df_ridelogs_match.head()
# Out:
#          ride_date                                          rider_url  \
# trail_id
# 1-87-dh      Jul 5          https://www.trailforks.com/profile/BCpov/
# 1-87-dh      Jul 5       https://www.trailforks.com/profile/canadaka/
# 1-87-dh     May 27   https://www.trailforks.com/profile/campasternak/
# 1-87-dh     May 21   https://www.trailforks.com/profile/campasternak/
# 1-87-dh     May 20  https://www.trailforks.com/profile/superlightr...
#
#                rider_name rider_state rider_city  \
# trail_id
# 1-87-dh             BCpov          BC     Duncan
# 1-87-dh          canadaka          BC     Duncan
# 1-87-dh      campasternak          BC     Duncan
# 1-87-dh      campasternak          BC     Duncan
# 1-87-dh   superlightracer          BC     Duncan
#
#                   ride_difficulty_string
# trail_id
# 1-87-dh   Very Difficult / Black Diamond
# 1-87-dh   Very Difficult / Black Diamond
# 1-87-dh   Very Difficult / Black Diamond
# 1-87-dh   Very Difficult / Black Diamond
# 1-87-dh   Very Difficult / Black Diamond

# %%
df_ridelogs_match.shape
# Out:
# (1266757, 6)

# %% [markdown]
# # Save to Postgres

# %%
# Define a database name (we're using a dataset on births, so we'll call it birth_db)
# Set your postgres username
dbname = 'trailrec'
username = 'briangraham' # change this to your username

# %%
## 'engine' is a connection to a database
## Here, we're using postgres, but sqlalchemy can connect to other things too.
engine = create_engine('postgres://%s@localhost/%s'%(username,dbname))
print(engine.url)
# Out:
# postgres://briangraham@localhost/trailrec

# %%
## create a database (if it doesn't exist)
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))
# Out:
# True

# %%
## insert data into database from Python (proof of concept - this won't be useful for big data, of course)
df_trail.to_sql('trails', engine, if_exists='replace')
df_comments_filtered.to_sql('comments', engine, if_exists='replace')
df_ridelogs_match.to_sql('ridelogs', engine, if_exists='replace')

# %%
# Connect to make queries using psycopg2
conn = psycopg2.connect("host=localhost dbname=trailrec user=briangraham")
cur = conn.cursor()

# %%
# query:
sql_query = """
SELECT * FROM trails;
"""
birth_data_from_sql = pd.read_sql_query(sql_query,conn)
birth_data_from_sql.tail()
# Out:
#                      trail_id Altitude change Altitude end Altitude max  \
# 2797            zig-zag-27113          -71 ft       732 ft       804 ft
# 2798               ziggy-8689         -416 ft     3,186 ft     3,608 ft
# 2799  zolapalusa-extra-crispy         -711 ft     2,952 ft     3,781 ft
# 2800             zoot-allures          -31 ft     2,262 ft     2,292 ft
# 2801                     zoso          -11 ft       457 ft       476 ft
#
#      Altitude min Altitude start Avg reverse time  Avg time    Bike type  \
# 2797       731 ft         803 ft             None  00:05:14       DH, AM
# 2798     3,186 ft       3,602 ft         00:22:46  00:05:49       AM, XC
# 2799     2,952 ft       3,663 ft             None  00:15:54       AM, XC
# 2800     2,262 ft       2,292 ft         00:01:33  00:00:58       AM, XC
# 2801       446 ft         468 ft         00:02:16  00:01:56  AM, XC, Fat
#
#       Difficulty rating      ...       descent  \
# 2797  Black Diamondrate      ...        -73 ft
# 2798           Bluerate      ...       -432 ft
# 2799  Black Diamondrate      ...       -931 ft
# 2800           Bluerate      ...        -34 ft
# 2801           Bluerate      ...        -34 ft
#
#                                             description  distance   latitude  \
# 2797  Well built DH style trail with optional ride a...  2,107 ft  48.409780
# 2798  In the Spring and early Summer, you will get m...  4,833 ft  50.086962
# 2799  This trail is for hiking and mountain biking. ...   1 miles  50.840090
# 2800  This trail is one of many riding options surro...    599 ft  50.135020
# 2801  Twisty, rolly, mildly technical, and open. Nic...    968 ft  48.521230
#
#        longitude rating state votes Climb Difficulty Distance flat
# 2797 -123.679800   5.00    BC     7             None        332 ft
# 2798 -120.854856   4.65    BC     3             None          None
# 2799 -122.881470   3.00    BC     1             None      1,368 ft
# 2800 -122.943790   4.35    BC     6             None        165 ft
# 2801 -123.459380   3.00    BC     1             None        218 ft
#
# [5 rows x 36 columns]

# %%
birth_data_from_sql['description'].iloc[0]
# Out:
# 'One of the original Pidherny trails.'
